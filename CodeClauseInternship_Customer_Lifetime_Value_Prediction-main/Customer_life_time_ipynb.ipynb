# %%
import sklearn
import pandas as pd
df=pd.read_csv("insurance-ltv-decrease.csv")
df
# Out:
#            id  gender   area qualification  income  marital_status  vintage  \
# 0        1001  Female  Urban      Bachelor  5L-10L               0        2
# 1        1002    Male  Urban   High School  5L-10L               1        5
# 2        1003  Female  Rural      Bachelor   2L-5L               0        6
# 3        1004    Male  Rural   High School  5L-10L               1        2
# 4        1005    Male  Rural      Bachelor  5L-10L               0        2
# ...       ...     ...    ...           ...     ...             ...      ...
# 98410  106019    Male  Urban      Bachelor  5L-10L               0        5
# 98411  106020    Male  Rural   High School  5L-10L               1        7
# 98412  106021    Male  Urban   High School  5L-10L               1        7
# 98413  106022    Male  Urban   High School  5L-10L               0        7
# 98414  106023    Male  Urban      Bachelor  5L-10L               0        2
#
#        claim_amount num_policies policy type_of_policy          cltv
# 0       8405.000000  More than 1      A       Platinum   64896.00000
# 1       6281.000000            1      B       Platinum   47676.00000
# 2       2099.000000  More than 1      B       Platinum   69600.00000
# 3       4087.000000  More than 1      B       Platinum   70692.00000
# 4          0.000000  More than 1      A       Platinum   40644.00000
# ...             ...          ...    ...            ...           ...
# 98410   1471.178514            1      A       Platinum   46934.51484
# 98411   1632.917172  More than 1      A           Gold   49151.96973
# 98412   5161.583106            1      A       Platinum   27442.92625
# 98413   4755.561493  More than 1      A           Gold   59348.72834
# 98414   2435.587977  More than 1      C           Gold  128785.08570
#
# [98415 rows x 12 columns]

# %%
df.shape
# Out:
# (98415, 12)

# %%
df.income.value_counts()
# Out:
# income
# 5L-10L           57987
# 2L-5L            23343
# More than 10L    15014
# <=2L              2071
# Name: count, dtype: int64

# %%
df.loc[13933].income
cond=df['income'] == '<=2L'
df=df[cond==False]
df.income.value_counts()
# Out:
# income
# 5L-10L           57987
# 2L-5L            23343
# More than 10L    15014
# Name: count, dtype: int64

# %%
df['income']=df['income'].map({'2L-5L':'2L-5L','5L-10L':'5L-10L','More than 10L': '10L-25L'})
df.income.unique()
# Out:
# <ipython-input-5-dcdf4f976360>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['income']=df['income'].map({'2L-5L':'2L-5L','5L-10L':'5L-10L','More than 10L': '10L-25L'})
# array(['5L-10L', '2L-5L', '10L-25L'], dtype=object)

# %%
df.columns
# Out:
# Index(['id', 'gender', 'area', 'qualification', 'income', 'marital_status',
#        'vintage', 'claim_amount', 'num_policies', 'policy', 'type_of_policy',
#        'cltv'],
#       dtype='object')

# %%
df[['lower_income','higher_income']]=df['income'].str.split('-',n=1,expand=True)
df['higher_income']=df['higher_income'].str.rstrip('L')
df['lower_income']=df['lower_income'].str.rstrip('L')

df.sample()
# Out:
# <ipython-input-7-cdc8bbb7b731>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['lower_income','higher_income']]=df['income'].str.split('-',n=1,expand=True)
# <ipython-input-7-cdc8bbb7b731>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['lower_income','higher_income']]=df['income'].str.split('-',n=1,expand=True)
# <ipython-input-7-cdc8bbb7b731>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['higher_income']=df['higher_income'].str.rstrip('L')
# <ipython-input-7-cdc8bbb7b731>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lower_income']=df['lower_income'].str.rstrip('L')
#           id gender   area qualification  income  marital_status  vintage  \
# 44998  45999   Male  Urban      Bachelor  5L-10L               1        5
#
#        claim_amount num_policies policy type_of_policy     cltv lower_income  \
# 44998        3899.0  More than 1      A           Gold  97356.0            5
#
#       higher_income
# 44998            10

# %%
df=df.drop('income',axis=1)
df.columns
# Out:
# Index(['id', 'gender', 'area', 'qualification', 'marital_status', 'vintage',
#        'claim_amount', 'num_policies', 'policy', 'type_of_policy', 'cltv',
#        'lower_income', 'higher_income'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 96344 entries, 0 to 98414
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              96344 non-null  int64
#  1   gender          96344 non-null  object
#  2   area            96344 non-null  object
#  3   qualification   96344 non-null  object
#  4   marital_status  96344 non-null  int64
#  5   vintage         96344 non-null  int64
#  6   claim_amount    96344 non-null  float64
#  7   num_policies    96344 non-null  object
#  8   policy          96344 non-null  object
#  9   type_of_policy  96344 non-null  object
#  10  cltv            96344 non-null  float64
#  11  lower_income    96344 non-null  object
#  12  higher_income   96344 non-null  object
# dtypes: float64(2), int64(3), object(8)
# memory usage: 10.3+ MB

# %%
df.isnull().sum()
# Out:
# id                0
# gender            0
# area              0
# qualification     0
# marital_status    0
# vintage           0
# claim_amount      0
# num_policies      0
# policy            0
# type_of_policy    0
# cltv              0
# lower_income      0
# higher_income     0
# dtype: int64

# %%
df.higher_income.unique()
df.lower_income.unique()
# Out:
# array(['5', '2', '10'], dtype=object)

# %%
df
# Out:
#            id  gender   area qualification  marital_status  vintage  \
# 0        1001  Female  Urban      Bachelor               0        2
# 1        1002    Male  Urban   High School               1        5
# 2        1003  Female  Rural      Bachelor               0        6
# 3        1004    Male  Rural   High School               1        2
# 4        1005    Male  Rural      Bachelor               0        2
# ...       ...     ...    ...           ...             ...      ...
# 98410  106019    Male  Urban      Bachelor               0        5
# 98411  106020    Male  Rural   High School               1        7
# 98412  106021    Male  Urban   High School               1        7
# 98413  106022    Male  Urban   High School               0        7
# 98414  106023    Male  Urban      Bachelor               0        2
#
#        claim_amount num_policies policy type_of_policy          cltv  \
# 0       8405.000000  More than 1      A       Platinum   64896.00000
# 1       6281.000000            1      B       Platinum   47676.00000
# 2       2099.000000  More than 1      B       Platinum   69600.00000
# 3       4087.000000  More than 1      B       Platinum   70692.00000
# 4          0.000000  More than 1      A       Platinum   40644.00000
# ...             ...          ...    ...            ...           ...
# 98410   1471.178514            1      A       Platinum   46934.51484
# 98411   1632.917172  More than 1      A           Gold   49151.96973
# 98412   5161.583106            1      A       Platinum   27442.92625
# 98413   4755.561493  More than 1      A           Gold   59348.72834
# 98414   2435.587977  More than 1      C           Gold  128785.08570
#
#       lower_income higher_income
# 0                5            10
# 1                5            10
# 2                2             5
# 3                5            10
# 4                5            10
# ...            ...           ...
# 98410            5            10
# 98411            5            10
# 98412            5            10
# 98413            5            10
# 98414            5            10
#
# [96344 rows x 13 columns]

# %%
df['gender']=df['gender'].map({'Male':1,'Female':0})
df['area']=df['area'].map({'Rural':0,'Urban':1})
df['qualification']=df['qualification'].map({'Bachelor':0,'High School':1,'Others':2})
df['num_policies']=df['num_policies'].map({'More than 1':0,'1':1})
df['policy']=df['policy'].map({'A':0,'B':1,'C':2})
df['type_of_policy']=df['type_of_policy'].map({'Platinum':2,'Gold':1,'Silver':0})
df['higher_income']=df['higher_income'].map({'10':10,'5':5,'25':25})
df['lower_income']=df['lower_income'].map({'5':5,'2':2,'10':10})

df.sample(10)
# Out:
#           id  gender  area  qualification  marital_status  vintage  \
# 21879  22880       1     1              0               1        5
# 12949  13950       0     0              0               1        1
# 10132  11133       1     0              0               0        7
# 6230    7231       1     0              0               0        8
# 54378  55379       1     0              0               1        8
# 75750  76751       1     1              0               0        7
# 2608    3609       0     1              0               1        6
# 89345  96954       0     1              1               1        1
# 53044  54045       1     0              2               0        3
# 33968  34969       1     1              1               1        1
#
#        claim_amount  num_policies  policy  type_of_policy          cltv  \
# 21879   3602.000000             0       0               1   48516.00000
# 12949   3133.000000             0       0               1   62472.00000
# 10132      0.000000             0       1               2  194052.00000
# 6230    2452.000000             0       1               1  105696.00000
# 54378   2481.000000             1       2               1   37488.00000
# 75750   5457.000000             1       0               2   46860.00000
# 2608       0.000000             1       0               2   54036.00000
# 89345   3478.125691             0       0               2   85285.42892
# 53044      0.000000             1       0               0   59892.00000
# 33968  13346.000000             0       1               2  146772.00000
#
#        lower_income  higher_income
# 21879             2              5
# 12949             5             10
# 10132             5             10
# 6230             10             25
# 54378             5             10
# 75750             5             10
# 2608              5             10
# 89345             5             10
# 53044            10             25
# 33968             2              5

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

model=LinearRegression()
t=df['cltv']
feat=df[['gender', 'area', 'qualification','marital_status','claim_amount','num_policies', 'type_of_policy','higher_income','lower_income']]

X_train, X_test, y_train, y_test = train_test_split(feat, t, test_size=0.150, random_state=30)

model.fit(X_train,y_train)
s=model.predict(X_test)

r2 = r2_score(y_test,s)
print("The r2 score is :",r2)
# Out:
# The r2 score is : 0.15065757453623996

# %%
X_test.columns
# Out:
# Index(['gender', 'area', 'qualification', 'marital_status', 'claim_amount',
#        'num_policies', 'type_of_policy', 'higher_income', 'lower_income'],
#       dtype='object')

# %%
print("CUSTOMER VALUE PREDICTION ")
print()
gender=int(input("1 for male and 0 for female :"))
area=int(input("1 for urban and 0 for rural :"))
qualification=int(input("2 for others, 1 for high school, 0 for bachelor :"))
marital=int(input("1 for married and 0 for unmarried :"))
claim_amount=float(input("Claim amount :"))
num_policies=int(input("No fo policies : 1 for 1 and 0 for more than 1 :"))
type_policies=int(input("Type of policy : 2 for platinum, 1 for gold and 0 for silver :"))
higherincome=int(input("Higher income : 10 , 5 , 25 :"))
lowerincome=int(input("Lower income : 2 5 10 :"))

testing = pd.DataFrame({
    'gender': [gender],
    'area': [area],
    'qualification': [qualification],
    'marital_status': [marital],
    'claim_amount': [claim_amount],
    'num_policies': [num_policies],
    'type_of_policy': [type_policies],
    'higher_income': [higherincome],
    'lower_income': [lowerincome]
})

ans = model.predict(testing)
print("/nPredicted customer value : ", ans)
# Out:
# CUSTOMER VALUE PREDICTION
#
# 1 for male and 0 for female :1
# 1 for urban and 0 for rural :1
# 2 for others, 1 for high school, 0 for bachelor :2
# 1 for married and 0 for unmarried :1
# Claim amount :1111
# No fo policies : 1 for 1 and 0 for more than 1 :1
# Type of policy : 2 for platinum, 1 for gold and 0 for silver :1
# Higher income : 10 , 5 , 25 :1
# Lower income : 2 5 10 :2
# /nPredicted customer value :  [43212.55225881]
